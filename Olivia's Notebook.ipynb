# %%
import numpy as np
import pandas as pd

school= pd.read_csv("enrollment.csv")
school.drop(columns=['african_american','american_indian','asian__not_pacific_islander', 
                    'hispanic','multiracial','native_hawaiian_or_other_pacific_islander', 'white'])
# Out:
#             neighborhood  total_students_enrolled student_count_redactions  \
# 0       Allegheny Center                      NaN                        Y
# 1         Allegheny West                      NaN                        N
# 2              Allentown                      NaN                        Y
# 3              Arlington                      NaN                        Y
# 4      Arlington Heights                      NaN                        N
# ..                   ...                      ...                      ...
# 355             West End                      NaN                        Y
# 356         West Oakland                     14.0                        Y
# 357             Westwood                     62.0                        Y
# 358  Wilkinsburg Borough                    194.0                        Y
# 359              Windgap                     31.0                        Y
#
#      attending_feeder  attending_nonfeeder  total_with_feeder_status  \
# 0                 NaN                  NaN                       NaN
# 1                 NaN                  NaN                       NaN
# 2                 NaN                  NaN                       NaN
# 3                 NaN                  NaN                       NaN
# 4                 NaN                  NaN                       NaN
# ..                ...                  ...                       ...
# 355               NaN                  NaN                       NaN
# 356               NaN                  NaN                      14.0
# 357              41.0                 21.0                      62.0
# 358               NaN                  NaN                     194.0
# 359              19.0                 12.0                      31.0
#
#     feeder_count_redactions grade_level
# 0                       NaN       Pre-K
# 1                       NaN       Pre-K
# 2                       NaN       Pre-K
# 3                       NaN       Pre-K
# 4                       NaN       Pre-K
# ..                      ...         ...
# 355                       Y      12-Sep
# 356                       Y      12-Sep
# 357                     NaN      12-Sep
# 358                       Y      12-Sep
# 359                     NaN      12-Sep
#
# [360 rows x 8 columns]
