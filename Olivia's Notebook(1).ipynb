# %%
import numpy as np
import pandas as pd

school= pd.read_csv("enrollment.csv")
student_enrollment = school.drop(columns=['african_american','american_indian','asian__not_pacific_islander', 
                    'hispanic','multiracial','native_hawaiian_or_other_pacific_islander', 'white'])

student_enrollment.groupby("neighborhood").count()
# Out:
#                      total_students_enrolled  student_count_redactions  \
# neighborhood
# Allegheny Center                           3                         4
# Allegheny West                             0                         4
# Allentown                                  3                         4
# Arlington                                  3                         4
# Arlington Heights                          1                         4
# ...                                      ...                       ...
# West End                                   1                         4
# West Oakland                               3                         4
# Westwood                                   4                         4
# Wilkinsburg Borough                        3                         4
# Windgap                                    4                         4
#
#                      attending_feeder  attending_nonfeeder  \
# neighborhood
# Allegheny Center                    1                    1
# Allegheny West                      0                    0
# Allentown                           3                    3
# Arlington                           3                    3
# Arlington Heights                   0                    0
# ...                               ...                  ...
# West End                            0                    0
# West Oakland                        1                    1
# Westwood                            3                    3
# Wilkinsburg Borough                 0                    0
# Windgap                             3                    3
#
#                      total_with_feeder_status  feeder_count_redactions  \
# neighborhood
# Allegheny Center                            3                        2
# Allegheny West                              0                        3
# Allentown                                   3                        0
# Arlington                                   3                        0
# Arlington Heights                           1                        3
# ...                                       ...                      ...
# West End                                    1                        3
# West Oakland                                3                        2
# Westwood                                    3                        0
# Wilkinsburg Borough                         3                        3
# Windgap                                     3                        0
#
#                      grade_level
# neighborhood
# Allegheny Center               4
# Allegheny West                 4
# Allentown                      4
# Arlington                      4
# Arlington Heights              4
# ...                          ...
# West End                       4
# West Oakland                   4
# Westwood                       4
# Wilkinsburg Borough            4
# Windgap                        4
#
# [91 rows x 7 columns]
